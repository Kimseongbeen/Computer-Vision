# %% [markdown]
# # **OpenCV 시작하기**
#
# 1. Python에서 OpenCV 모델 가져오기
# 2. 이미지 로드
# 3. 이미지 표시
# 4. 이미지 저장
# 5. 이미지 치수 가져오기

# %%
# 라이브러리를 설치하지 못하면 사용하지 못한다.
import cv2

# %%
# cv2의 버전을 출력, 잘 설치됐는지 확인용.
print(cv2.__version__)
# Out:
# 4.8.0

# %% [markdown]
# ### **Dowloading Images**
#
# If using Google Colab, we'll have to **upload our image**.
#
# Colab is a Jupyther Notebook environment that runs on the **cloud** using Google's servers. As such, any file we wish to use needs to be uploaded to their servers.

# %%
# Google Drive에서 다운로드
# 다운로드 받은 파일 압축해제
# !gdown --id 1O2uCujErifjvK1ziRGssaQO9khI15g6q
# !unzip -qq images.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q
# From (redirected): https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q&confirm=t&uuid=0310c959-0347-4864-a388-771403c84452
# To: /content/images.zip
# 100% 29.6M/29.6M [00:00<00:00, 132MB/s]

# %% [markdown]
# ### **Loading Images**

# %%
# image라는 변수에 다운로드 받은 이미지 하나 넣어주기
image = cv2.imread('./images/castara.jpeg')

# %% [markdown]
# ### **Displaying Images**

# %%
from matplotlib import pyplot as plt

# matplotlib를 사용하여 이미지를 출력하기
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Let's create a simple function to make displaying our images simpler and easier

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# 함수 불러오기
imshow("saved image", image)

# %% [markdown]
# ### **Saving Images**

# %%
# 파일 이름과 저장할 이미지를 지정하는 'imwrite'를 사용하기만 하면 된다.
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
# 또는 무손실 비트맵 이미지 형식인 PNG(Portable Network Graphics)로 저장
cv2.imwrite('output.png', image)
# Out:
# True

# %% [markdown]
# ### **Displaying Image Dimensions**
#
# Remember Images are arrays:
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/array.png?token=ADLZD2HNEL33JAKTYRM3B5C7WMIV4)

# %% [markdown]
# We need to use numpy to perform this operation. Don't worry, numpy will become one of your best friends if you're learning a Data Science and Computer Vision.

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (1280, 960, 3)

# %%
# To access a dimension, simply index it by using 0, 1 or 2.
print(image.shape[0])
print(image.shape[1])
print(image.shape[2])
# Out:
# 1280
# 960
# 3

# %% [markdown]
# You can see the first dimension is the height and it's 960 pixels
#
# The second dimension is the width which is 1280 pixels.
#
# We can print them out nicely like this:

# %%
print('이미지의 높이: {} pixels'.format(int(image.shape[0])))
print('이미지의 넓이: {} pixels'.format(int(image.shape[1])))
print('이미지의 깊이: {} colors components'.format(int(image.shape[2])))
# Out:
# 이미지의 높이: 1280 pixels
# 이미지의 넓이: 960 pixels
# 이미지의 깊이: 3 colors components
